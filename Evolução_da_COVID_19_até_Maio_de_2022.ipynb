# %% [markdown]
# # **Importando pacotes**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Preparando os datasets para trabalhar**

# %% [markdown]
# ## **Importando e lendo o dataset da evolução diária do COVID-19**

# %%
main_dataset = pd.read_csv("worldometer_coronavirus_daily_data.csv", sep = ",")
main_dataset
# Out:
#              date      country  cumulative_total_cases  daily_new_cases  \
# 0       2020-2-15  Afghanistan                     0.0              NaN
# 1       2020-2-16  Afghanistan                     0.0              NaN
# 2       2020-2-17  Afghanistan                     0.0              NaN
# 3       2020-2-18  Afghanistan                     0.0              NaN
# 4       2020-2-19  Afghanistan                     0.0              NaN
# ...           ...          ...                     ...              ...
# 184782  2022-5-10     Zimbabwe                248642.0            106.0
# 184783  2022-5-11     Zimbabwe                248778.0            136.0
# 184784  2022-5-12     Zimbabwe                248943.0            165.0
# 184785  2022-5-13     Zimbabwe                249131.0            188.0
# 184786  2022-5-14     Zimbabwe                249206.0             75.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths
# 0                0.0                      0.0               NaN
# 1                0.0                      0.0               NaN
# 2                0.0                      0.0               NaN
# 3                0.0                      0.0               NaN
# 4                0.0                      0.0               NaN
# ...              ...                      ...               ...
# 184782         963.0                   5481.0               2.0
# 184783        1039.0                   5481.0               0.0
# 184784        1158.0                   5481.0               0.0
# 184785        1283.0                   5482.0               1.0
# 184786        1307.0                   5482.0               0.0
#
# [184787 rows x 7 columns]

# %% [markdown]
# ## **Importando e lendo o dataset com o total da população em cada continente**

# %%
population_total = pd.read_csv("population.csv", sep = ",")
population_total = population_total[["country", "population"]]
population_total = population_total.reset_index()
population_total.drop(columns = ["index"], inplace = True)
population_total = population_total.set_index("country")

# %% [markdown]
# ## **Criando um novo DataFrame com números sobre os casos ativos em cada país no dia mais recente no dataset**

# %%
active_cases_covid = main_dataset[["date", "country", "active_cases"]].copy()
active_cases_covid["date"] = pd.to_datetime(active_cases_covid["date"], format= "%Y-%m-%d")

#Selecting the most recently day present in each country
last_date = active_cases_covid.groupby(["country"])["date"].transform(max) == active_cases_covid["date"]
active_cases_covid = active_cases_covid[last_date]

#Reseting the index, rewriting with the name of countries, and deleting the previous column "index"
active_cases_covid = active_cases_covid.reset_index()
active_cases_covid.drop(columns = ["index"], inplace = True)
active_cases_covid = active_cases_covid.set_index("country")
active_cases_covid.head(10)
# Out:
# /tmp/ipykernel_1577/1126402852.py:5: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   last_date = active_cases_covid.groupby(["country"])["date"].transform(max) == active_cases_covid["date"]
#                           date  active_cases
# country
# Afghanistan         2022-05-14        9398.0
# Albania             2022-05-14         251.0
# Algeria             2022-05-14       80570.0
# Andorra             2022-05-14         982.0
# Angola              2022-05-14         145.0
# Anguilla            2022-05-14          59.0
# Antigua And Barbuda 2022-05-14          73.0
# Argentina           2022-05-14       76591.0
# Armenia             2022-05-14        2225.0
# Aruba               2022-05-14         281.0

# %% [markdown]
# ## **Criando um outro DataFrame com o total de casos e mortes em casa país**

# %%
sum_total_cases_covid_country = main_dataset[["country", "daily_new_cases", "daily_new_deaths"]]
sum_total_cases_covid_country = sum_total_cases_covid_country.groupby("country").sum()
sum_total_cases_covid_country.head(10)
# Out:
#                      daily_new_cases  daily_new_deaths
# country
# Afghanistan                 179242.0            7690.0
# Albania                     275572.0            3496.0
# Algeria                     265815.0            6875.0
# Andorra                      42155.0             153.0
# Angola                       99193.0            1898.0
# Anguilla                      2982.0               8.0
# Antigua And Barbuda           7720.0             136.0
# Argentina                  9101318.0          128728.0
# Armenia                     422895.0            8623.0
# Aruba                        35691.0             212.0

# %% [markdown]
# ## **Juntando dois DataFrames com o total de casos, mortes e casos ativos no dia mais recente**

# %%
total_cases_covid_country = pd.merge(sum_total_cases_covid_country, active_cases_covid, left_index = True, right_index = True).merge(population_total, on = "country")
total_cases_covid_country.drop(columns = ["date"], inplace = True)
total_cases_covid_country.rename(columns = {"daily_new_cases" : "total_cases", "daily_new_deaths" : "total_deaths"}, inplace = True)
total_cases_covid_country.head(10)
# Out:
#              total_cases  total_deaths  active_cases  population
# country
# Afghanistan     179242.0        7690.0        9398.0    39074280
# Albania         275572.0        3496.0         251.0     2877239
# Algeria         265815.0        6875.0       80570.0    43984569
# Andorra          42155.0         153.0         982.0       77287
# Angola           99193.0        1898.0         145.0    33032075
# Anguilla          2982.0           8.0          59.0       15026
# Argentina      9101318.0      128728.0       76591.0    45267449
# Armenia         422895.0        8623.0        2225.0     2964219
# Aruba            35691.0         212.0         281.0      106845
# Australia      6551609.0        7773.0      391667.0    25550683

# %% [markdown]
# ## **Calculando a taxa de incidência e a mortalidade**

# %%
total_cases_covid_country["incidence_rate"] = total_cases_covid_country["total_cases"] / total_cases_covid_country["population"] * 100000
total_cases_covid_country["mortality_rate"] = total_cases_covid_country["total_deaths"] / total_cases_covid_country["population"] * 100000
total_cases_covid_country.head(10)
# Out:
#              total_cases  total_deaths  active_cases  population  \
# country
# Afghanistan     179242.0        7690.0        9398.0    39074280
# Albania         275572.0        3496.0         251.0     2877239
# Algeria         265815.0        6875.0       80570.0    43984569
# Andorra          42155.0         153.0         982.0       77287
# Angola           99193.0        1898.0         145.0    33032075
# Anguilla          2982.0           8.0          59.0       15026
# Argentina      9101318.0      128728.0       76591.0    45267449
# Armenia         422895.0        8623.0        2225.0     2964219
# Aruba            35691.0         212.0         281.0      106845
# Australia      6551609.0        7773.0      391667.0    25550683
#
#              incidence_rate  mortality_rate
# country
# Afghanistan      458.721184       19.680465
# Albania         9577.654133      121.505374
# Algeria          604.336944       15.630482
# Andorra        54543.454915      197.963435
# Angola           300.292973        5.745930
# Anguilla       19845.600958       53.241049
# Argentina      20105.656937      284.372110
# Armenia        14266.658435      290.902933
# Aruba          33404.464411      198.418269
# Australia      25641.619835       30.421887

# %% [markdown]
# ## **Criando um DataFrame com a evolução dos casos ao longo do tempo desde 2020**

# %%
evolution_cases_covid_country = main_dataset[["date", "country", "daily_new_cases", "active_cases", "daily_new_deaths"]].copy()
evolution_cases_covid_country["date"] = pd.to_datetime(evolution_cases_covid_country["date"], format= "%Y-%m-%d")
evolution_cases_covid_country
# Out:
#              date      country  daily_new_cases  active_cases  \
# 0      2020-02-15  Afghanistan              NaN           0.0
# 1      2020-02-16  Afghanistan              NaN           0.0
# 2      2020-02-17  Afghanistan              NaN           0.0
# 3      2020-02-18  Afghanistan              NaN           0.0
# 4      2020-02-19  Afghanistan              NaN           0.0
# ...           ...          ...              ...           ...
# 184782 2022-05-10     Zimbabwe            106.0         963.0
# 184783 2022-05-11     Zimbabwe            136.0        1039.0
# 184784 2022-05-12     Zimbabwe            165.0        1158.0
# 184785 2022-05-13     Zimbabwe            188.0        1283.0
# 184786 2022-05-14     Zimbabwe             75.0        1307.0
#
#         daily_new_deaths
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 184782               2.0
# 184783               0.0
# 184784               0.0
# 184785               1.0
# 184786               0.0
#
# [184787 rows x 5 columns]

# %% [markdown]
# ## **Importando um DataFrame com o total de vacinação ao redor do mundo**

# %%
covid_vaccinated = pd.read_csv("vaccinations.csv")
covid_vaccinated["date"] = pd.to_datetime(covid_vaccinated["date"], format= "%Y-%m-%d")
covid_vaccinated
# Out:
#            location iso_code       date  total_vaccinations  \
# 0       Afghanistan      AFG 2021-02-22                 0.0
# 1       Afghanistan      AFG 2021-02-23                 NaN
# 2       Afghanistan      AFG 2021-02-24                 NaN
# 3       Afghanistan      AFG 2021-02-25                 NaN
# 4       Afghanistan      AFG 2021-02-26                 NaN
# ...             ...      ...        ...                 ...
# 102761     Zimbabwe      ZWE 2022-05-14          11153964.0
# 102762     Zimbabwe      ZWE 2022-05-15          11336359.0
# 102763     Zimbabwe      ZWE 2022-05-16          11456837.0
# 102764     Zimbabwe      ZWE 2022-05-17          11489104.0
# 102765     Zimbabwe      ZWE 2022-05-18          11568719.0
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                     0.0                      NaN             NaN
# 1                     NaN                      NaN             NaN
# 2                     NaN                      NaN             NaN
# 3                     NaN                      NaN             NaN
# 4                     NaN                      NaN             NaN
# ...                   ...                      ...             ...
# 102761          6067791.0                4191100.0        895073.0
# 102762          6117318.0                4299107.0        919934.0
# 102763          6153538.0                4366541.0        936758.0
# 102764          6166141.0                4380681.0        942282.0
# 102765          6187713.0                4421292.0        959714.0
#
#         daily_vaccinations_raw  daily_vaccinations  \
# 0                          NaN                 NaN
# 1                          NaN              1367.0
# 2                          NaN              1367.0
# 3                          NaN              1367.0
# 4                          NaN              1367.0
# ...                        ...                 ...
# 102761                147695.0             86306.0
# 102762                182395.0            103783.0
# 102763                120478.0            119063.0
# 102764                 32267.0            107103.0
# 102765                 79615.0            107876.0
#
#         total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                                 0.00                           0.00
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 102761                           73.91                          40.20
# 102762                           75.11                          40.53
# 102763                           75.91                          40.77
# 102764                           76.13                          40.86
# 102765                           76.65                          41.00
#
#         people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# ...                                     ...                         ...
# 102761                                27.77                        5.93
# 102762                                28.49                        6.10
# 102763                                28.93                        6.21
# 102764                                29.03                        6.24
# 102765                                29.30                        6.36
#
#         daily_vaccinations_per_million  daily_people_vaccinated  \
# 0                                  NaN                      NaN
# 1                                 34.0                   1367.0
# 2                                 34.0                   1367.0
# 3                                 34.0                   1367.0
# 4                                 34.0                   1367.0
# ...                                ...                      ...
# 102761                          5719.0                  22547.0
# 102762                          6877.0                  27868.0
# 102763                          7889.0                  32116.0
# 102764                          7097.0                  30372.0
# 102765                          7148.0                  29699.0
#
#         daily_people_vaccinated_per_hundred
# 0                                       NaN
# 1                                     0.003
# 2                                     0.003
# 3                                     0.003
# 4                                     0.003
# ...                                     ...
# 102761                                0.149
# 102762                                0.185
# 102763                                0.213
# 102764                                0.201
# 102765                                0.197
#
# [102766 rows x 16 columns]

# %% [markdown]
# ## **Escolhendo as principais informações sobre a vacinação para colocar no dataset**

# %%
covid_vaccinated_world = covid_vaccinated[["location", "date", "total_vaccinations", "people_vaccinated", "people_fully_vaccinated",  "total_boosters", "daily_vaccinations_raw"]]
covid_vaccinated_world
# Out:
#            location       date  total_vaccinations  people_vaccinated  \
# 0       Afghanistan 2021-02-22                 0.0                0.0
# 1       Afghanistan 2021-02-23                 NaN                NaN
# 2       Afghanistan 2021-02-24                 NaN                NaN
# 3       Afghanistan 2021-02-25                 NaN                NaN
# 4       Afghanistan 2021-02-26                 NaN                NaN
# ...             ...        ...                 ...                ...
# 102761     Zimbabwe 2022-05-14          11153964.0          6067791.0
# 102762     Zimbabwe 2022-05-15          11336359.0          6117318.0
# 102763     Zimbabwe 2022-05-16          11456837.0          6153538.0
# 102764     Zimbabwe 2022-05-17          11489104.0          6166141.0
# 102765     Zimbabwe 2022-05-18          11568719.0          6187713.0
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw
# 0                           NaN             NaN                     NaN
# 1                           NaN             NaN                     NaN
# 2                           NaN             NaN                     NaN
# 3                           NaN             NaN                     NaN
# 4                           NaN             NaN                     NaN
# ...                         ...             ...                     ...
# 102761                4191100.0        895073.0                147695.0
# 102762                4299107.0        919934.0                182395.0
# 102763                4366541.0        936758.0                120478.0
# 102764                4380681.0        942282.0                 32267.0
# 102765                4421292.0        959714.0                 79615.0
#
# [102766 rows x 7 columns]

# %% [markdown]
# ## **Além dos DataFrames com o número de casos de COVID-19, foi feito um novo DataFrame com o total de vacinações em cada país até o dia mais recente presente no dataset**

# %%
last_date = covid_vaccinated_world.groupby(["location"])["date"].transform(max) == covid_vaccinated_world["date"]
total_covid_vaccinated_world = covid_vaccinated_world[last_date]

total_covid_vaccinated_world = total_covid_vaccinated_world.reset_index()
total_covid_vaccinated_world.drop(columns = ["index"], inplace = True)
total_covid_vaccinated_world = total_covid_vaccinated_world.set_index("location")
total_covid_vaccinated_world
# Out:
# /tmp/ipykernel_1577/3583344103.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   last_date = covid_vaccinated_world.groupby(["location"])["date"].transform(max) == covid_vaccinated_world["date"]
#                         date  total_vaccinations  people_vaccinated  \
# location
# Afghanistan       2022-05-15        6.066579e+06       5.359930e+06
# Africa            2022-05-19        4.974869e+08       3.072735e+08
# Albania           2022-05-01        2.825500e+06       1.299321e+06
# Algeria           2022-05-01        1.520585e+07       7.840131e+06
# Andorra           2022-05-01        1.526940e+05       5.787400e+04
# ...                      ...                 ...                ...
# Wallis and Futuna 2022-05-02        1.642600e+04                NaN
# World             2022-05-19        1.174946e+10       5.171542e+09
# Yemen             2022-05-11        8.286870e+05       6.630040e+05
# Zambia            2022-05-16        4.029757e+06                NaN
# Zimbabwe          2022-05-18        1.156872e+07       6.187713e+06
#
#                    people_fully_vaccinated  total_boosters  \
# location
# Afghanistan                   4.710456e+06             NaN
# Africa                        2.342889e+08    2.373727e+07
# Albania                       1.230636e+06    2.955430e+05
# Algeria                       6.481186e+06    5.140630e+05
# Andorra                       5.342700e+04    4.139300e+04
# ...                                    ...             ...
# Wallis and Futuna                      NaN    3.201000e+03
# World                         4.704080e+09    1.938782e+09
# Yemen                         4.256190e+05             NaN
# Zambia                        2.564717e+06             NaN
# Zimbabwe                      4.421292e+06    9.597140e+05
#
#                    daily_vaccinations_raw
# location
# Afghanistan                           NaN
# Africa                                NaN
# Albania                               NaN
# Algeria                               NaN
# Andorra                               NaN
# ...                                   ...
# Wallis and Futuna                     NaN
# World                                 NaN
# Yemen                                 NaN
# Zambia                                NaN
# Zimbabwe                          79615.0
#
# [235 rows x 6 columns]

# %% [markdown]
# ## **Incluindo as informações sobre a população total nos países no dataset de vacinação mundial**

# %%
total_covid_vaccinated_world = total_covid_vaccinated_world.join(population_total)
total_covid_vaccinated_world
# Out:
#                         date  total_vaccinations  people_vaccinated  \
# location
# Afghanistan       2022-05-15        6.066579e+06       5.359930e+06
# Africa            2022-05-19        4.974869e+08       3.072735e+08
# Albania           2022-05-01        2.825500e+06       1.299321e+06
# Algeria           2022-05-01        1.520585e+07       7.840131e+06
# Andorra           2022-05-01        1.526940e+05       5.787400e+04
# ...                      ...                 ...                ...
# Wallis and Futuna 2022-05-02        1.642600e+04                NaN
# World             2022-05-19        1.174946e+10       5.171542e+09
# Yemen             2022-05-11        8.286870e+05       6.630040e+05
# Zambia            2022-05-16        4.029757e+06                NaN
# Zimbabwe          2022-05-18        1.156872e+07       6.187713e+06
#
#                    people_fully_vaccinated  total_boosters  \
# location
# Afghanistan                   4.710456e+06             NaN
# Africa                        2.342889e+08    2.373727e+07
# Albania                       1.230636e+06    2.955430e+05
# Algeria                       6.481186e+06    5.140630e+05
# Andorra                       5.342700e+04    4.139300e+04
# ...                                    ...             ...
# Wallis and Futuna                      NaN    3.201000e+03
# World                         4.704080e+09    1.938782e+09
# Yemen                         4.256190e+05             NaN
# Zambia                        2.564717e+06             NaN
# Zimbabwe                      4.421292e+06    9.597140e+05
#
#                    daily_vaccinations_raw  population
# location
# Afghanistan                           NaN  39074280.0
# Africa                                NaN         NaN
# Albania                               NaN   2877239.0
# Algeria                               NaN  43984569.0
# Andorra                               NaN     77287.0
# ...                                   ...         ...
# Wallis and Futuna                     NaN         NaN
# World                                 NaN         NaN
# Yemen                                 NaN  29935468.0
# Zambia                                NaN  18468257.0
# Zimbabwe                          79615.0  14899771.0
#
# [235 rows x 7 columns]

# %% [markdown]
# ## **Porém, há alguns index diferentes porque em cada dataset há um nome diferente escrito. Então vamos corrigir os nomes manualmente para conectar as informações!**

# %%
def rename_country(country):
	if country == "Bonaire Sint Eustatius and Saba":
		return "Caribbean Netherlands"
	if country == "Cape Verde":
		return "Cabo Verde"
	if country == "Cote d'Ivoire":
		return "Côte d'Ivoire"
	if country == "Curacao":
		return "Curaçao"
	if country == "Czechia":
		return "Czech Republic"
	if country == "Democratic Republic of Congo":
		return "DR Congo"
	if country == "Palestine":
		return "State of Palestine"
	if country == "Saint Kitts and Nevis":
		return "Saint Kitts & Nevis"
	if country == "Saint Vincent and the Grenadines":
		return "St. Vincent & Grenadines"
	if country == "Sao Tome and Principe":
		return "Sao Tome & Principe"
	if country == "Sint Maarten (Dutch part)":
		return "Sint Maarten"
	if country == "Timor":
		return "Timor-Leste"
	if country == "Turks and Caicos Islands":
		return "Turks and Caicos"
	if country == "Wallis and Futuna":
		return "Wallis & Futuna"
	return country

total_covid_vaccinated_world["correct_location"] = total_covid_vaccinated_world.index.map(rename_country)
total_covid_vaccinated_world
# Out:
#                         date  total_vaccinations  people_vaccinated  \
# location
# Afghanistan       2022-05-15        6.066579e+06       5.359930e+06
# Africa            2022-05-19        4.974869e+08       3.072735e+08
# Albania           2022-05-01        2.825500e+06       1.299321e+06
# Algeria           2022-05-01        1.520585e+07       7.840131e+06
# Andorra           2022-05-01        1.526940e+05       5.787400e+04
# ...                      ...                 ...                ...
# Wallis and Futuna 2022-05-02        1.642600e+04                NaN
# World             2022-05-19        1.174946e+10       5.171542e+09
# Yemen             2022-05-11        8.286870e+05       6.630040e+05
# Zambia            2022-05-16        4.029757e+06                NaN
# Zimbabwe          2022-05-18        1.156872e+07       6.187713e+06
#
#                    people_fully_vaccinated  total_boosters  \
# location
# Afghanistan                   4.710456e+06             NaN
# Africa                        2.342889e+08    2.373727e+07
# Albania                       1.230636e+06    2.955430e+05
# Algeria                       6.481186e+06    5.140630e+05
# Andorra                       5.342700e+04    4.139300e+04
# ...                                    ...             ...
# Wallis and Futuna                      NaN    3.201000e+03
# World                         4.704080e+09    1.938782e+09
# Yemen                         4.256190e+05             NaN
# Zambia                        2.564717e+06             NaN
# Zimbabwe                      4.421292e+06    9.597140e+05
#
#                    daily_vaccinations_raw  population correct_location
# location
# Afghanistan                           NaN  39074280.0      Afghanistan
# Africa                                NaN         NaN           Africa
# Albania                               NaN   2877239.0          Albania
# Algeria                               NaN  43984569.0          Algeria
# Andorra                               NaN     77287.0          Andorra
# ...                                   ...         ...              ...
# Wallis and Futuna                     NaN         NaN  Wallis & Futuna
# World                                 NaN         NaN            World
# Yemen                                 NaN  29935468.0            Yemen
# Zambia                                NaN  18468257.0           Zambia
# Zimbabwe                          79615.0  14899771.0         Zimbabwe
#
# [235 rows x 8 columns]

# %%
total_covid_vaccinated_world = total_covid_vaccinated_world.reset_index()
total_covid_vaccinated_world.drop(columns = ["location"], inplace = True)
total_covid_vaccinated_world = total_covid_vaccinated_world.set_index("correct_location")
total_covid_vaccinated_world = total_covid_vaccinated_world.rename_axis("country")
total_covid_vaccinated_world
# Out:
#                       date  total_vaccinations  people_vaccinated  \
# country
# Afghanistan     2022-05-15        6.066579e+06       5.359930e+06
# Africa          2022-05-19        4.974869e+08       3.072735e+08
# Albania         2022-05-01        2.825500e+06       1.299321e+06
# Algeria         2022-05-01        1.520585e+07       7.840131e+06
# Andorra         2022-05-01        1.526940e+05       5.787400e+04
# ...                    ...                 ...                ...
# Wallis & Futuna 2022-05-02        1.642600e+04                NaN
# World           2022-05-19        1.174946e+10       5.171542e+09
# Yemen           2022-05-11        8.286870e+05       6.630040e+05
# Zambia          2022-05-16        4.029757e+06                NaN
# Zimbabwe        2022-05-18        1.156872e+07       6.187713e+06
#
#                  people_fully_vaccinated  total_boosters  \
# country
# Afghanistan                 4.710456e+06             NaN
# Africa                      2.342889e+08    2.373727e+07
# Albania                     1.230636e+06    2.955430e+05
# Algeria                     6.481186e+06    5.140630e+05
# Andorra                     5.342700e+04    4.139300e+04
# ...                                  ...             ...
# Wallis & Futuna                      NaN    3.201000e+03
# World                       4.704080e+09    1.938782e+09
# Yemen                       4.256190e+05             NaN
# Zambia                      2.564717e+06             NaN
# Zimbabwe                    4.421292e+06    9.597140e+05
#
#                  daily_vaccinations_raw  population
# country
# Afghanistan                         NaN  39074280.0
# Africa                              NaN         NaN
# Albania                             NaN   2877239.0
# Algeria                             NaN  43984569.0
# Andorra                             NaN     77287.0
# ...                                 ...         ...
# Wallis & Futuna                     NaN         NaN
# World                               NaN         NaN
# Yemen                               NaN  29935468.0
# Zambia                              NaN  18468257.0
# Zimbabwe                        79615.0  14899771.0
#
# [235 rows x 7 columns]

# %% [markdown]
# ## **Selecionando os países aonde tem informações da população total com o total de pessoas vacinadas**

# %%
total_covid_vaccinated_world = total_covid_vaccinated_world[total_covid_vaccinated_world["population"].notna()]
total_covid_vaccinated_world = total_covid_vaccinated_world.query("people_fully_vaccinated > 0")
total_covid_vaccinated_world
# Out:
#                   date  total_vaccinations  people_vaccinated  \
# country
# Afghanistan 2022-05-15           6066579.0          5359930.0
# Albania     2022-05-01           2825500.0          1299321.0
# Algeria     2022-05-01          15205854.0          7840131.0
# Andorra     2022-05-01            152694.0            57874.0
# Angola      2022-04-26          17896626.0         12059919.0
# ...                ...                 ...                ...
# Venezuela   2022-03-25          37860994.0         22157232.0
# Vietnam     2022-05-15         216959400.0         82886620.0
# Yemen       2022-05-11            828687.0           663004.0
# Zambia      2022-05-16           4029757.0                NaN
# Zimbabwe    2022-05-18          11568719.0          6187713.0
#
#              people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# country
# Afghanistan                4710456.0             NaN                     NaN
# Albania                    1230636.0        295543.0                     NaN
# Algeria                    6481186.0        514063.0                     NaN
# Andorra                      53427.0         41393.0                     NaN
# Angola                     6327907.0        369899.0                     NaN
# ...                              ...             ...                     ...
# Venezuela                 14287370.0        651502.0                     NaN
# Vietnam                   78673094.0      55399686.0                     NaN
# Yemen                       425619.0             NaN                     NaN
# Zambia                     2564717.0             NaN                     NaN
# Zimbabwe                   4421292.0        959714.0                 79615.0
#
#              population
# country
# Afghanistan  39074280.0
# Albania       2877239.0
# Algeria      43984569.0
# Andorra         77287.0
# Angola       33032075.0
# ...                 ...
# Venezuela    28421581.0
# Vietnam      97490013.0
# Yemen        29935468.0
# Zambia       18468257.0
# Zimbabwe     14899771.0
#
# [194 rows x 7 columns]

# %% [markdown]
# ## **Calculando o percentual de vacinação nos países**

# %%
total_covid_vaccinated_world["percent_people_fully_vaccinated"] = (total_covid_vaccinated_world["people_fully_vaccinated"] / total_covid_vaccinated_world["population"]) * 100
total_covid_vaccinated_world.sort_values("percent_people_fully_vaccinated", ascending = False)
# Out:
#                            date  total_vaccinations  people_vaccinated  \
# country
# Gibraltar            2022-04-21            119855.0            42074.0
# Malta                2022-05-18           1290118.0           475989.0
# United Arab Emirates 2022-05-19          24787714.0          9890557.0
# Brunei               2022-05-06           1124061.0           432057.0
# Samoa                2022-05-16            477369.0           228234.0
# ...                         ...                 ...                ...
# Madagascar           2022-05-15           2369775.0          1290584.0
# Papua New Guinea     2022-04-18            586000.0           322687.0
# Yemen                2022-05-11            828687.0           663004.0
# Haiti                2022-05-06            275632.0           181322.0
# Burundi              2022-05-08             12651.0            12651.0
#
#                       people_fully_vaccinated  total_boosters  \
# country
# Gibraltar                             41421.0         36360.0
# Malta                                468884.0        379608.0
# United Arab Emirates                9682855.0       5214302.0
# Brunei                               409091.0        282887.0
# Samoa                                181891.0         67244.0
# ...                                       ...             ...
# Madagascar                          1156975.0         26792.0
# Papua New Guinea                     263313.0             NaN
# Yemen                                425619.0             NaN
# Haiti                                127003.0             NaN
# Burundi                               12078.0             NaN
#
#                       daily_vaccinations_raw  population  \
# country
# Gibraltar                                NaN     33689.0
# Malta                                 1064.0    441750.0
# United Arab Emirates                  3501.0   9910892.0
# Brunei                                   NaN    438202.0
# Samoa                                    NaN    198643.0
# ...                                      ...         ...
# Madagascar                               NaN  27808395.0
# Papua New Guinea                         NaN   8975531.0
# Yemen                                    NaN  29935468.0
# Haiti                                    NaN  11426356.0
# Burundi                                  NaN  11948454.0
#
#                       percent_people_fully_vaccinated
# country
# Gibraltar                                  122.951112
# Malta                                      106.142388
# United Arab Emirates                        97.699127
# Brunei                                      93.356717
# Samoa                                       91.566781
# ...                                               ...
# Madagascar                                   4.160524
# Papua New Guinea                             2.933676
# Yemen                                        1.421788
# Haiti                                        1.111492
# Burundi                                      0.101084
#
# [194 rows x 8 columns]

# %% [markdown]
# # **Ilustrando as informações**

# %%
total_cases_covid_country_over_10_million = total_cases_covid_country.query("population >= 10000000")

fig, ax = plt.subplots(1, figsize=(15, 6))
total_cases_covid_country_over_10_million["incidence_rate"].sort_values(ascending = False)[0:20].plot(kind = "bar", color = "orangered")
plt.title("As 20 maiores taxas de incidência em países com população acima de 10 milhões", fontsize = 20)
plt.xlabel("Os 20 maiores países", fontsize = 12)
plt.ylabel("Taxa de incidência", fontsize = 12)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,6))
total_cases_covid_country_over_10_million["mortality_rate"].sort_values(ascending = False)[0:20].plot(kind = "bar", color = "darkred")
plt.title("As 20 maiores taxas de mortalidade em países com população acima de 10 milhões", fontsize = 20)
plt.xlabel("Os 20 maiores países", fontsize = 12)
plt.ylabel("Taxa de mortalidade", fontsize = 12)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,6))
total_covid_vaccinated_world["percent_people_fully_vaccinated"].sort_values(ascending = False)[0:20].plot(kind = "bar", color = "dodgerblue")
plt.title("Os 20 países com maior percentagem de população totalmente vacinada", fontsize = 20)
plt.xlabel("Os primeiros 20 países")
plt.ylabel("Percentagem")
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Calculando a percentagem de pessoas vacinadas entre as que receberam a dose de reforço (3x), vacinação completa (2x), apenas uma dose (1x) e não vacinada**

# %%
total_covid_vaccinated_world_most_population = total_covid_vaccinated_world.nlargest(20, "population")
graph_covid_vaccinated_world_20_most_population = total_covid_vaccinated_world_most_population[["people_vaccinated", "people_fully_vaccinated", "total_boosters", "population"]].copy()
graph_covid_vaccinated_world_20_most_population["percent_total_boosters"] = total_covid_vaccinated_world_most_population["total_boosters"] / total_covid_vaccinated_world_most_population["population"] * 100
graph_covid_vaccinated_world_20_most_population["percent_people_fully_vaccinated"] = (total_covid_vaccinated_world_most_population["people_fully_vaccinated"] - total_covid_vaccinated_world_most_population["total_boosters"]) / total_covid_vaccinated_world_most_population["population"] * 100
graph_covid_vaccinated_world_20_most_population["percent_people_vaccinated"] = (total_covid_vaccinated_world_most_population["people_vaccinated"] - total_covid_vaccinated_world_most_population["people_fully_vaccinated"]) / total_covid_vaccinated_world_most_population["population"] * 100
graph_covid_vaccinated_world_20_most_population["percent_people_unvaccinated"] = (total_covid_vaccinated_world_most_population["population"] - total_covid_vaccinated_world_most_population["people_vaccinated"]) / total_covid_vaccinated_world_most_population["population"] * 100
graph_percents_population = graph_covid_vaccinated_world_20_most_population[["percent_people_vaccinated", "percent_people_fully_vaccinated", "percent_total_boosters", "percent_people_unvaccinated"]]
graph_percents_population = graph_percents_population.fillna(0)
graph_percents_population
# Out:
#                 percent_people_vaccinated  percent_people_fully_vaccinated  \
# country
# India                            9.440315                        61.336198
# United States                   11.246187                        35.699316
# Indonesia                       12.133908                        47.088791
# Pakistan                         5.403551                        52.007855
# Brazil                           8.360744                        33.804904
# Nigeria                          5.113257                         7.669957
# Bangladesh                       7.193493                        62.492247
# Russia                           5.080076                        40.600454
# Japan                            1.224693                        23.503573
# Ethiopia                         3.013370                        18.144491
# Philippines                      0.000000                        50.173660
# Egypt                           11.578374                        30.989726
# Vietnam                          4.322008                        23.872607
# Turkey                           5.656094                        19.270104
# Iran                             7.972720                        36.090360
# Germany                          0.064328                        12.178562
# Thailand                         6.255544                        35.624476
# United Kingdom                   5.140429                        15.261469
# France                           2.436539                        22.566060
# Italy                            4.720444                        12.715777
#
#                 percent_total_boosters  percent_people_unvaccinated
# country
# India                         2.196188                    27.027299
# United States                30.942421                    22.112075
# Indonesia                    13.670022                    27.107279
# Pakistan                      3.407314                    39.181281
# Brazil                       43.935334                    13.899018
# Nigeria                       0.455285                    86.761501
# Bangladesh                    8.456585                    21.857675
# Russia                        9.818347                    44.501123
# Japan                        57.105751                    18.165982
# Ethiopia                      0.300093                    78.542046
# Philippines                  12.503377                     0.000000
# Egypt                         2.844165                    54.587734
# Vietnam                      56.826012                    14.979373
# Turkey                       43.521054                    31.552749
# Iran                         32.530021                    23.406898
# Germany                      64.730148                    23.026962
# Thailand                     38.817592                    19.302388
# United Kingdom               58.095149                    21.502953
# France                       58.274552                    16.722848
# Italy                        66.567486                    15.996293

# %%
plt.subplots(1, figsize=(20, 12))
plt.title("Número de vacinados entre o 20 países mais populosos do mundo", fontsize = 18)
plt.bar(graph_percents_population.index, graph_percents_population["percent_people_unvaccinated"], color = "gray", width = 0.5, label="Não-vacinados")
plt.bar(graph_percents_population.index, graph_percents_population["percent_people_vaccinated"], color = "goldenrod", bottom=graph_percents_population["percent_people_unvaccinated"], width = 0.5, label="Apenas uma dose (1x)")
plt.bar(graph_percents_population.index, graph_percents_population["percent_people_fully_vaccinated"], color = "forestgreen", bottom=graph_percents_population["percent_people_unvaccinated"]+graph_percents_population["percent_people_vaccinated"], width = 0.5, label="Completamente vacinados (2x)")
plt.bar(graph_percents_population.index, graph_percents_population["percent_total_boosters"], color = "royalblue", width = 0.5, bottom=graph_percents_population["percent_people_unvaccinated"]+graph_percents_population["percent_people_vaccinated"]+graph_percents_population["percent_people_fully_vaccinated"], label="Receberam a dose de reforço (3x)")
plt.legend(loc=1, fontsize = 12)
plt.xlabel("Os primeiros 20 países", fontsize = 12)
plt.ylabel("Taxa de incidência", fontsize = 12)
plt.grid(True)
plt.show()

# %% [markdown]
# # **Explorando os dados do Brasil durante a pandemia**

# %%
evolution_cases_covid_brazil = evolution_cases_covid_country.query("country == 'Brazil'").copy()
evolution_cases_covid_brazil["total_cases_per_day"] = evolution_cases_covid_brazil["daily_new_cases"].cumsum()
evolution_cases_covid_brazil["total_deaths_per_day"] = evolution_cases_covid_brazil["daily_new_deaths"].cumsum()
evolution_cases_covid_brazil["moving_average_cases_7_days_previous"] = evolution_cases_covid_brazil["daily_new_cases"].rolling(window=7).mean()
evolution_cases_covid_brazil["moving_average_deaths_7_days_previous"] = evolution_cases_covid_brazil["daily_new_deaths"].rolling(window=7).mean()
evolution_cases_covid_brazil = evolution_cases_covid_brazil.reset_index()
evolution_cases_covid_brazil.drop(columns = ["index"], inplace = True)
evolution_cases_covid_brazil = evolution_cases_covid_brazil.set_index("date")

# %%
evolution_cases_covid_brazil_after_first_vaccinate = evolution_cases_covid_brazil.query("date >= '2021-1-17'")
evolution_cases_covid_brazil_after_first_vaccinate
# Out:
#            country  daily_new_cases  active_cases  daily_new_deaths  \
# date
# 2021-01-17  Brazil          31736.0      893522.0             518.0
# 2021-01-18  Brazil          24450.0      876994.0             460.0
# 2021-01-19  Brazil          63986.0      872791.0            1183.0
# 2021-01-20  Brazil          64611.0      890102.0            1382.0
# 2021-01-21  Brazil          60413.0      933011.0            1335.0
# ...            ...              ...           ...               ...
# 2022-05-10  Brazil          20143.0      248825.0             195.0
# 2022-05-11  Brazil          23398.0      255291.0             121.0
# 2022-05-12  Brazil          21344.0      270526.0             136.0
# 2022-05-13  Brazil          25609.0      288171.0             130.0
# 2022-05-14  Brazil          17355.0      298772.0              90.0
#
#             total_cases_per_day  total_deaths_per_day  \
# date
# 2021-01-17            8538007.0              209868.0
# 2021-01-18            8562457.0              210328.0
# 2021-01-19            8626443.0              211511.0
# 2021-01-20            8691054.0              212893.0
# 2021-01-21            8751467.0              214228.0
# ...                         ...                   ...
# 2022-05-10           30594387.0              664443.0
# 2022-05-11           30617785.0              664564.0
# 2022-05-12           30639129.0              664700.0
# 2022-05-13           30664738.0              664830.0
# 2022-05-14           30682093.0              664920.0
#
#             moving_average_cases_7_days_previous  \
# date
# 2021-01-17                          55059.142857
# 2021-01-18                          54499.000000
# 2021-01-19                          54742.857143
# 2021-01-20                          55073.428571
# 2021-01-21                          53823.714286
# ...                                          ...
# 2022-05-10                          15994.142857
# 2022-05-11                          16469.285714
# 2022-05-12                          16421.000000
# 2022-05-13                          17261.571429
# 2022-05-14                          17652.000000
#
#             moving_average_deaths_7_days_previous
# date
# 2021-01-17                             961.142857
# 2021-01-18                             958.714286
# 2021-01-19                             969.285714
# 2021-01-20                             983.428571
# 2021-01-21                            1009.714286
# ...                                           ...
# 2022-05-10                              96.857143
# 2022-05-11                             106.857143
# 2022-05-12                             104.714286
# 2022-05-13                              98.142857
# 2022-05-14                             105.857143
#
# [483 rows x 8 columns]

# %%
vaccination_brazil = covid_vaccinated_world[["location", "date", "total_vaccinations", "people_fully_vaccinated"]].query("location=='Brazil'")
vaccination_brazil = vaccination_brazil.reset_index()
vaccination_brazil.drop(columns = ["index"], inplace = True)
vaccination_brazil = vaccination_brazil.set_index("date")
vaccination_brazil
# Out:
#            location  total_vaccinations  people_fully_vaccinated
# date
# 2021-01-17   Brazil               112.0                      NaN
# 2021-01-18   Brazil              1109.0                      NaN
# 2021-01-19   Brazil             13527.0                      NaN
# 2021-01-20   Brazil            105824.0                      NaN
# 2021-01-21   Brazil            193699.0                      NaN
# ...             ...                 ...                      ...
# 2022-05-15   Brazil         435243423.0              165173312.0
# 2022-05-16   Brazil         435312095.0              165182832.0
# 2022-05-17   Brazil                 NaN                      NaN
# 2022-05-18   Brazil         436276886.0              165396479.0
# 2022-05-19   Brazil         436936651.0              165448319.0
#
# [488 rows x 3 columns]

# %%
fig = plt.figure(figsize=(15, 9))

death_axis = fig.add_axes([0,0,1,1])
vaccinate_axis = fig.add_axes([0.5, 0.4, 0.5, 0.5])

deaths_before_may_2021 = evolution_cases_covid_brazil_after_first_vaccinate.query("date < '2021-05-01'")
deaths_before_july_2021 = evolution_cases_covid_brazil_after_first_vaccinate.query("date < '2021-07-01'")
vaccinate_before_may_2021 = vaccination_brazil.query("date < '2021-05-01'")
vaccinate_before_july_2021 = vaccination_brazil.query("date < '2021-07-01'")

death_axis.grid(True)
death_axis.plot(evolution_cases_covid_brazil_after_first_vaccinate["moving_average_deaths_7_days_previous"], color = "seagreen", label = "À medida que a campanha de vacinação aumentou ao longo do tempo, a média móvel de casos e mortes também diminuiu")
death_axis.plot(deaths_before_july_2021["moving_average_deaths_7_days_previous"], color = "darkorange", label = "Dois meses depois, a porcentagem de casos e mortes diminuiu 24%, ao mesmo tempo que a porcentagem da população totalmente vacinada subiu para 12,5%")
death_axis.plot(deaths_before_may_2021["moving_average_deaths_7_days_previous"], color = "maroon", label = "Apesar da campanha de vacinação ter começado há 4 meses, apenas 7,5% da população brasileira estava totalmente vacinada")
death_axis.set_title("Média móvel de óbitos por COVID-19 no Brasil após o início da vacinação", fontsize = 26, pad = 20)
death_axis.set_ylabel("Número de mortes", fontsize = 14)
death_axis.set_xlabel("Data", fontsize = 14)
death_axis.legend(loc=3, fontsize = 12)

vaccinate_axis.grid(True)
vaccinate_axis.plot(vaccination_brazil["people_fully_vaccinated"].dropna(), color = "seagreen")
vaccinate_axis.plot(vaccinate_before_july_2021["people_fully_vaccinated"], color = "darkorange")
vaccinate_axis.plot(vaccinate_before_may_2021["people_fully_vaccinated"], color = "maroon")
vaccinate_axis.set_title("Pessoas totalmente vacinadas contra a COVID-19", fontsize = 16, pad = 20)
vaccinate_axis.set_ylabel("Número de pessoas totalmente vacinadas (por milhão)", fontsize = 14)
vaccinate_axis.set_xlabel("Data", fontsize = 16)
vaccinate_axis.legend(["Vacina"], loc = "upper left", fontsize = 12)
